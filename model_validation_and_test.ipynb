# %%
# !pip install -r /content/drive/MyDrive/simple_htr/SimpleHTR-master/requirements.txt

# %%
# %cd /content/drive/MyDrive/simple_htr/SimpleHTR-master/src
# Out:
# /content/drive/MyDrive/simple_htr/SimpleHTR-master/src

# %%
# !python main.py
# Out:
# 2021-05-17 00:44:57.347014: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/legacy_tf_layers/normalization.py:308: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
#   '`tf.layers.batch_normalization` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1719: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ...

# %%
# !pwd
# Out:
# /content/drive/My Drive/simple_htr/SimpleHTR-master/src

# %%
# !python main.py --validate --data_dir /content/drive/MyDrive/simple_htr/SimpleHTR-master/datasets --dump
# Out:
# Streaming output truncated to the last 5000 lines.
# [ERR:2] "disbelieve" -> "dibelievd"
# [OK] "the" -> "the"
# [ERR:1] "facts" -> "fact"
# [ERR:1] "." -> ","
# [ERR:1] "'" -> "E"
# [ERR:1] "Elation" -> "lation"
# [OK] "touched" -> "touched"
# [OK] "him" -> "him"
# [OK] "after" -> "after"
# [OK] "the" -> "the"
# [OK] "cold" -> "cold"
# [OK] "wind" -> "wind"
# [OK] "of" -> "of"
# [ERR:2] "suspense" -> "susgsense"
# [OK] "." -> "."
# [ERR:1] "'" -> ","
# [ERR:1] "It" -> "I"
# [OK] "will" -> "will"
# [OK] "be" -> "be"
# [OK] "interesting" -> "interesting"
# [OK] "to" -> "to"
# [ERR:1] "see" -> "zee"
# [OK] "what" -> "what"
# [OK] "comes" -> "comes"
# [OK] "out" -> "out"
# [OK] "at" -> "at"
# [OK] "the" -> "the"
# [ERR:4] "inquest" -> "egrest"
# [OK] "." -> "."
# [OK] "What" -> "What"
# [OK] "his" -> "his"
# [OK] "story" -> "story"
# [OK] "will" -> "will"
# [OK] "be" -> "be"
# [OK] "." -> "."
# Batch: 10 / 58
# Ground truth -> Recognized
# [OK] "I" -> "I"
# [ERR:1] "reckon" -> "rechon"
# ...
